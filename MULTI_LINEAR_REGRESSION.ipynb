# %% [markdown]
# ## IDE used - jupyter Notebook#

# %% [markdown]
# PROBLEM 1#

# %%
import pandas as pd
import numpy as np

# %%
##loading the dataset#
startup= pd.read_csv('D:\\DATA SCIENCE ASSIGNMENT\\Datasets_MLR\\50_Startups.csv')

# %%
startup.head(5)
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
startup.tail(5)
# Out:
#     R&D Spend  Administration  Marketing Spend       State    Profit
# 45    1000.23       124153.04          1903.93    New York  64926.08
# 46    1315.46       115816.21        297114.46     Florida  49490.75
# 47       0.00       135426.92             0.00  California  42559.73
# 48     542.05        51743.15             0.00    New York  35673.41
# 49       0.00       116983.80         45173.06  California  14681.40

# %%
startup.columns
# Out:
# Index(['R&D Spend', 'Administration', 'Marketing Spend', 'State', 'Profit'], dtype='object')

# %%
##let do label encoding for categorical data#
from sklearn.preprocessing import LabelEncoder

# %%
L_enc = LabelEncoder()

# %%
startup['State']= L_enc.fit_transform(startup['State'])

# %%
##EDA#
startup.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend      State  \
# count      50.000000       50.000000        50.000000  50.000000
# mean    73721.615600   121344.639600    211025.097800   1.000000
# std     45902.256482    28017.802755    122290.310726   0.832993
# min         0.000000    51283.140000         0.000000   0.000000
# 25%     39936.370000   103730.875000    129300.132500   0.000000
# 50%     73051.080000   122699.795000    212716.240000   1.000000
# 75%    101602.800000   144842.180000    299469.085000   2.000000
# max    165349.200000   182645.560000    471784.100000   2.000000
#
#               Profit
# count      50.000000
# mean   112012.639200
# std     40306.180338
# min     14681.400000
# 25%     90138.902500
# 50%    107978.190000
# 75%    139765.977500
# max    192261.830000

# %%
##altering columns name- R&d Spend and Marketing spend
cols = {'R&D Spend':'RD_Spend' , 'Marketing Spend' : 'Marketing_Spend' }
startup.rename(cols, axis= 1, inplace= True)

# %%
startup.columns
# Out:
# Index(['RD_Spend', 'Administration', 'Marketing_Spend', 'State', 'Profit'], dtype='object')

# %%
##Graphical representation#
import matplotlib.pyplot as plt

# %%
##RD Spend#
plt.bar(height= startup.RD_Spend, x= np.arange(1,51,1)) ##barplot#
# Out:
# <BarContainer object of 50 artists>

# %%
plt.hist(startup.RD_Spend)#histogram#
# Out:
# (array([6., 6., 4., 7., 8., 5., 3., 5., 3., 3.]),
#  array([     0.  ,  16534.92,  33069.84,  49604.76,  66139.68,  82674.6 ,
#          99209.52, 115744.44, 132279.36, 148814.28, 165349.2 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(startup.RD_Spend)##boxplot#
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a4f6b97f10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1a4f6bc04f0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1a4f6b97c40>],
#  'medians': [<matplotlib.lines.Line2D at 0x1a4f6bc0a90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a4f6bc0d60>],
#  'means': []}

# %%
#Administration#
plt.bar(height= startup.Administration, x= np.arange(1,51,1)) ##barplot
# Out:
# <BarContainer object of 50 artists>

# %%
plt.hist(startup.Administration)#histogram#
# Out:
# (array([ 2.,  1.,  3.,  7.,  7., 12.,  4., 11.,  2.,  1.]),
#  array([ 51283.14 ,  64419.382,  77555.624,  90691.866, 103828.108,
#         116964.35 , 130100.592, 143236.834, 156373.076, 169509.318,
#         182645.56 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(startup.Administration)##boxplot#
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a4f6d644c0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1a4f6d64a60>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1a4f6d641f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1a4f6d65000>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a4f6d652d0>],
#  'means': []}

# %%
#Marketing_Spend#
plt.bar(height= startup.Profit, x= np.arange(1,51,1)) ##barplot
# Out:
# <BarContainer object of 50 artists>

# %%
plt.hist(startup.Profit)#histogram#
# Out:
# (array([ 1.,  3.,  2.,  6., 10.,  8.,  7.,  7.,  2.,  4.]),
#  array([ 14681.4  ,  32439.443,  50197.486,  67955.529,  85713.572,
#         103471.615, 121229.658, 138987.701, 156745.744, 174503.787,
#         192261.83 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(startup.Profit)##boxplot#
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a4f6f04e80>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1a4f6f05420>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1a4f6f04bb0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1a4f6f059c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a4f6f05c90>],
#  'means': []}

# %%
#State#
plt.bar(height= startup.State, x= np.arange(1,51,1)) ##barplot
# Out:
# <BarContainer object of 50 artists>

# %%
plt.hist(startup.State)#histogram#
# Out:
# (array([17.,  0.,  0.,  0.,  0., 16.,  0.,  0.,  0., 17.]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(startup.State)##boxplot#
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a4f80676a0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1a4f8067c40>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1a4f80673d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1a4f80a0220>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a4f80a0460>],
#  'means': []}

# %%
##Jointplot
import seaborn as sns
sns.jointplot(x=startup['Administration'], y= startup['Profit'])

# %%
sns.jointplot(x=startup['Marketing_Spend'], y= startup['Profit'])

# %%
##countplot#
plt.figure(1,figsize=(16,10))
sns.countplot(startup['Marketing_Spend'])
# Out:
# C:\Users\Rakesh\.conda\envs\spyder-cf\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Marketing_Spend', ylabel='count'>

# %%
##Q-Q plot#
from scipy import stats

# %%
import pylab

# %%
stats.probplot(startup.Profit,dist= 'norm',plot=pylab)
plt.show()

# %%
##scatter plot ##
sns.pairplot(startup.iloc[:,:])

# %%
##correlation matrix#
startup.corr()
# Out:
#                  RD_Spend  Administration  Marketing_Spend     State    Profit
# RD_Spend         1.000000        0.241955         0.724248  0.104685  0.972900
# Administration   0.241955        1.000000        -0.032154  0.011847  0.200717
# Marketing_Spend  0.724248       -0.032154         1.000000  0.077670  0.747766
# State            0.104685        0.011847         0.077670  1.000000  0.101796
# Profit           0.972900        0.200717         0.747766  0.101796  1.000000

# %%
##preparing model for all variables#
##for regression model#
import statsmodels.formula.api as smf

# %%
ml1 = smf.ols('Profit~RD_Spend+Administration+Marketing_Spend+State', data= startup).fit()

# %%
ml1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.946
# Method:                 Least Squares   F-statistic:                     217.2
# Date:                Sat, 27 Aug 2022   Prob (F-statistic):           8.51e-29
# Time:                        20:29:30   Log-Likelihood:                -525.39
# No. Observations:                  50   AIC:                             1061.
# Df Residuals:                      45   BIC:                             1070.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %% [markdown]
# ##P values for state is more#

# %%
##checking for any influential values#
#influence index plots
import statsmodels.api as sm

# %%
sm.graphics.influence_plot(ml1)

# %% [markdown]
# # Studentized Residuals = Residual/standard deviation of residuals
# # index 49 , 48  is showing high influence so we can exclude that entire row

# %%
startup2 = startup.drop(startup.index[[49,48]])

# %%
##preparing model#
ml_new= smf.ols('Profit~RD_Spend+Administration+Marketing_Spend+State', data= startup2).fit()
ml_new.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.963
# Model:                            OLS   Adj. R-squared:                  0.959
# Method:                 Least Squares   F-statistic:                     277.7
# Date:                Sat, 27 Aug 2022   Prob (F-statistic):           4.18e-30
# Time:                        20:29:55   Log-Likelihood:                -493.30
# No. Observations:                  48   AIC:                             996.6
# Df Residuals:                      43   BIC:                             1006.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
# Check for Colinearity to decide to remove a variable using VIF
# Assumption: VIF > 10 = colinearity
# calculating VIF's values of independent variables
rsq_RD_Spend= smf.ols('RD_Spend~Administration+Marketing_Spend+State', data= startup).fit().rsquared
vif_rsq_RD_Spend = 1/(1-rsq_RD_Spend)

# %%
rsq_Administration= smf.ols('Administration~RD_Spend+Marketing_Spend+State', data= startup).fit().rsquared
vif_Administration = 1/(1-rsq_Administration)

# %%
rsq_Marketing_Spend= smf.ols('Marketing_Spend~Administration+RD_Spend+State', data= startup).fit().rsquared
vif_Marketing_Spend = 1/(1-rsq_Marketing_Spend)

# %%
rsq_State= smf.ols('State~Marketing_Spend+Administration+RD_Spend', data= startup).fit().rsquared
vif_State = 1/(1-rsq_State)

# %%
##storing VIF value in dataframe##
d1 = {'Variable':['RD_Spend','Administration','Marketing_Spend','State'], 'VIF':['vif_rsq_RD_Spend','vif_Administration','vif_Marketing_Spend','vif_State']}
Vif_frame= pd.DataFrame(d1)
Vif_frame
# Out:
#           Variable                  VIF
# 0         RD_Spend     vif_rsq_RD_Spend
# 1   Administration   vif_Administration
# 2  Marketing_Spend  vif_Marketing_Spend
# 3            State            vif_State

# %%
##Final Model#
final_ml= smf.ols('Profit~Administration+RD_Spend+Marketing_Spend+State', data= startup2).fit()
final_ml.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.963
# Model:                            OLS   Adj. R-squared:                  0.959
# Method:                 Least Squares   F-statistic:                     277.7
# Date:                Sat, 27 Aug 2022   Prob (F-statistic):           4.18e-30
# Time:                        20:46:14   Log-Likelihood:                -493.30
# No. Observations:                  48   AIC:                             996.6
# Df Residuals:                      43   BIC:                             1006.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
##prediction#
pred = final_ml.predict(startup)

# %%
##q-q plot#
res=final_ml.resid
sm.qqplot(res)
plt.show()

# %%
stats.probplot(res,dist='norm',plot = pylab)
plt.show()

# %%
##residual vs fitted plot#
sns.residplot(x=pred,y=startup.Profit, lowess=True)
plt.xlabel('Fitted')
plt.ylabel('Residual')
plt.title('FittedvsResidual')
plt.show()

# %%
sm.graphics.influence_plot(final_ml)

# %%
##split into train and test data#
from sklearn.model_selection import train_test_split

# %%
train,test = train_test_split(startup, test_size = 0.2)

# %%
##model on train data#
model_train = smf.ols('Profit~Administration+RD_Spend+Marketing_Spend+State', data= train).fit()

# %%
#prediction on test data#
test_pred =model_train.predict(test)

# %%
##test residual values#
test_resid = test_pred-test.Profit

# %%
##RMSE value for test data
test_rmse = np.sqrt(np.mean(test_resid*test_resid))
test_rmse
# Out:
# 10545.269931229166

# %%
#train data prediction#
train_pred=model_train.predict(train)

# %%
#train residual values#
train_resid = train_pred-train.Profit

# %%
##RMSE value for train data#
train_rmse = np.sqrt(np.mean(train_resid*train_resid))
train_rmse
# Out:
# 8593.660598837025

# %% [markdown]
# PROBLEM 2#

# %%
import pandas as pd
import numpy as np

# %%
comp = pd.read_csv('D:\\DATA SCIENCE ASSIGNMENT\\Datasets_MLR\\Computer_Data.csv')

# %%
comp.head(5)
# Out:
#    Unnamed: 0  price  speed   hd  ram  screen  cd multi premium  ads  trend
# 0           1   1499     25   80    4      14  no    no     yes   94      1
# 1           2   1795     33   85    2      14  no    no     yes   94      1
# 2           3   1595     25  170    4      15  no    no     yes   94      1
# 3           4   1849     25  170    8      14  no    no      no   94      1
# 4           5   3295     33  340   16      14  no    no     yes   94      1

# %%
comp.tail(5)
# Out:
#       Unnamed: 0  price  speed    hd  ram  screen   cd multi premium  ads  \
# 6254        6255   1690    100   528    8      15   no    no     yes   39
# 6255        6256   2223     66   850   16      15  yes   yes     yes   39
# 6256        6257   2654    100  1200   24      15  yes    no     yes   39
# 6257        6258   2195    100   850   16      15  yes    no     yes   39
# 6258        6259   2490    100   850   16      17  yes    no     yes   39
#
#       trend
# 6254     35
# 6255     35
# 6256     35
# 6257     35
# 6258     35

# %%
comp.describe()
# Out:
#         Unnamed: 0        price        speed           hd          ram  \
# count  6259.000000  6259.000000  6259.000000  6259.000000  6259.000000
# mean   3130.000000  2219.576610    52.011024   416.601694     8.286947
# std    1806.961999   580.803956    21.157735   258.548445     5.631099
# min       1.000000   949.000000    25.000000    80.000000     2.000000
# 25%    1565.500000  1794.000000    33.000000   214.000000     4.000000
# 50%    3130.000000  2144.000000    50.000000   340.000000     8.000000
# 75%    4694.500000  2595.000000    66.000000   528.000000     8.000000
# max    6259.000000  5399.000000   100.000000  2100.000000    32.000000
#
#             screen          ads        trend
# count  6259.000000  6259.000000  6259.000000
# mean     14.608723   221.301007    15.926985
# std       0.905115    74.835284     7.873984
# min      14.000000    39.000000     1.000000
# 25%      14.000000   162.500000    10.000000
# 50%      14.000000   246.000000    16.000000
# ...

# %%
##EDA#
comp= comp.iloc[:,1:]

# %%
#label encoding for categorical data # cd, multi, premium#
from sklearn.preprocessing import LabelEncoder

# %%
L_enc= LabelEncoder()

# %%
comp['cd'] = L_enc.fit_transform(comp['cd'])
comp['multi']=L_enc.fit_transform(comp['multi'])
comp['premium'] = L_enc.fit_transform(comp['premium'])

# %%
##Graphical representation#
import matplotlib.pyplot as plt

# %%
#price#
plt.bar(height= comp.price, x= np.arange(1,6260,1)) ##barplot#
# Out:
# <BarContainer object of 6259 artists>

# %%
plt.hist(comp.price) ##histogram#
# Out:
# (array([ 237., 1554., 1803., 1459.,  850.,  238.,   92.,   18.,    3.,
#            5.]),
#  array([ 949., 1394., 1839., 2284., 2729., 3174., 3619., 4064., 4509.,
#         4954., 5399.]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(comp.price)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2035c6074c0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2035c607a60>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2035c6071f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x2035c238040>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2035c238310>],
#  'means': []}

# %%
#speed#
plt.bar(height= comp.speed, x= np.arange(1,6260,1)) ##barplot#
# Out:
# <BarContainer object of 6259 artists>

# %%
plt.hist(comp.speed) ##histogram#
# Out:
# (array([ 566., 2033.,    0.,  994.,    0., 2028.,  122.,    0.,    0.,
#          516.]),
#  array([ 25. ,  32.5,  40. ,  47.5,  55. ,  62.5,  70. ,  77.5,  85. ,
#          92.5, 100. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(comp.speed)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20361573100>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x203615736a0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x20361571db0>],
#  'medians': [<matplotlib.lines.Line2D at 0x20361573c40>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20361573f10>],
#  'means': []}

# %%
#jointplot#
import seaborn as sns

# %%
sns.jointplot(x=comp['speed'],y=comp['price'])

# %%
#countplot#
plt.figure(1, figsize=(16,10))
sns.countplot(comp['hd'])
# Out:
# C:\Users\Rakesh\.conda\envs\spyder-cf\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='hd', ylabel='count'>

# %%
###Q-Q plot#
from scipy import stats
import pylab

# %%
stats.probplot(comp.price, dist= 'norm',plot=pylab)
plt.show()

# %%
##scatter plt btw variable#
sns.pairplot(comp.iloc[: ,:])

# %%
##correlation matrix#
comp.corr()
# Out:
#             price     speed        hd       ram    screen        cd     multi  \
# price    1.000000  0.300976  0.430258  0.622748  0.296041  0.197343 -0.016651
# speed    0.300976  1.000000  0.372304  0.234760  0.189074  0.258260  0.084172
# hd       0.430258  0.372304  1.000000  0.777726  0.232802  0.503570  0.092805
# ram      0.622748  0.234760  0.777726  1.000000  0.208954  0.438504  0.045497
# screen   0.296041  0.189074  0.232802  0.208954  1.000000  0.129488 -0.001740
# cd       0.197343  0.258260  0.503570  0.438504  0.129488  1.000000  0.432179
# multi   -0.016651  0.084172  0.092805  0.045497 -0.001740  0.432179  1.000000
# premium -0.080696  0.114208  0.196924  0.197145  0.018745  0.216077  0.124775
# ads      0.054540 -0.215232 -0.323222 -0.181670 -0.093919 -0.061091 -0.030394
# trend   -0.199987  0.405438  0.577790  0.276844  0.188614  0.445780  0.210907
#
#           premium       ads     trend
# price   -0.080696  0.054540 -0.199987
# ...

# %%
##preparing model#
import statsmodels.formula.api as smf #regression model#

# %%
ml1 =smf.ols('price~speed+hd+ram+screen+cd+multi+premium+ads+trend', data= comp).fit()
ml1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.776
# Model:                            OLS   Adj. R-squared:                  0.775
# Method:                 Least Squares   F-statistic:                     2399.
# Date:                Sun, 28 Aug 2022   Prob (F-statistic):               0.00
# Time:                        13:11:22   Log-Likelihood:                -44039.
# No. Observations:                6259   AIC:                         8.810e+04
# Df Residuals:                    6249   BIC:                         8.817e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    307.9880     60.353      5.103      0.000     189.675     426.301
# ...

# %%
# Check for Colinearity to decide to remove a variable using VIF
# Assumption: VIF > 10 = colinearity
# calculating VIF's values of independent variables
rsq_speed= smf.ols('speed~hd+ram+screen+cd+multi+premium+ads+trend', data=comp).fit().rsquared
vif_speed = 1/(1-rsq_speed)

# %%
rsq_hd= smf.ols('hd~speed+ram+screen+cd+multi+premium+trend', data=comp).fit().rsquared
vif_hd = 1/(1-rsq_hd)

# %%
rsq_ram= smf.ols('ram~speed+hd+screen+cd+multi+premium+trend', data=comp).fit().rsquared
vif_ram = 1/(1-rsq_ram)

# %%
rsq_screen= smf.ols('screen~speed+hd+ram+cd+multi+premium+trend', data=comp).fit().rsquared
vif_screen = 1/(1-rsq_screen)

# %%
rsq_cd= smf.ols('cd~speed+hd+ram+screen+multi+premium+trend', data=comp).fit().rsquared
vif_cd = 1/(1-rsq_cd)

# %%
rsq_multi= smf.ols('multi~speed+hd+ram+cd+screen+premium+trend', data=comp).fit().rsquared
vif_multi= 1/(1-rsq_multi)

# %%
rsq_premium= smf.ols('premium~speed+hd+ram+cd+multi+screen+trend', data=comp).fit().rsquared
vif_premium= 1/(1-rsq_premium)

# %%
rsq_trend= smf.ols('trend~speed+hd+ram+cd+multi+screen+premium', data=comp).fit().rsquared
vif_trend= 1/(1-rsq_trend)

# %%
comp.columns
# Out:
# Index(['price', 'speed', 'hd', 'ram', 'screen', 'cd', 'multi', 'premium',
#        'ads', 'trend'],
#       dtype='object')

# %%
# Storing vif values in a data frame
d1 = {'Variable':['speed','hd','ram','screen','cd','multi','premium','trend'], 'VIF':['vif_speed','vif_hd','vif_ram','vif_screen','vif_cd','vif_multi','vif_premium','vif_trend']}
Vif_frame= pd.DataFrame(d1)
Vif_frame
# Out:
#   Variable          VIF
# 0    speed    vif_speed
# 1       hd       vif_hd
# 2      ram      vif_ram
# 3   screen   vif_screen
# 4       cd       vif_cd
# 5    multi    vif_multi
# 6  premium  vif_premium
# 7    trend    vif_trend

# %%
#final model#
final_ml = smf.ols('price~speed+hd+ram+screen+cd+multi+premium+ads+trend', data= comp).fit()
final_ml.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.776
# Model:                            OLS   Adj. R-squared:                  0.775
# Method:                 Least Squares   F-statistic:                     2399.
# Date:                Sun, 28 Aug 2022   Prob (F-statistic):               0.00
# Time:                        13:31:09   Log-Likelihood:                -44039.
# No. Observations:                6259   AIC:                         8.810e+04
# Df Residuals:                    6249   BIC:                         8.817e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    307.9880     60.353      5.103      0.000     189.675     426.301
# ...

# %%
#prediction#
pred= final_ml.predict(comp)

# %%
##Q-Q plt#
res = final_ml.resid
sm.qqplot(res)
plt.show()

# %%
stats.probplot(res,dist = 'norm',plot = pylab)
plt.show()

# %%
##residual vs fitted#
sns.residplot(x=pred , y=comp.price, lowess= True)
plt.xlabel('Fitted')
plt.ylabel('Residual')
plt.title('Residual VS Fitted')
plt.show()

# %%
sm.graphics.influence_plot(final_ml)

# %%
##splitting into test and train
from sklearn.model_selection import train_test_split

# %%
train,test =train_test_split(comp , test_size= 0.2)

# %%
##preparing model on train data#
model_train = smf.ols("price ~ speed + hd + ram + screen + cd + multi + premium + trend", data = train).fit()

# %%
#prediction on test data#
test_pred = model_train.predict(test)

# %%
##test residual values#
test_resid= test_pred - test.price

# %%
##rmse value for test data#
test_rmse= np.sqrt(np.mean(test_resid*test_resid))
test_rmse
# Out:
# 275.54568546051854

# %%
##train data prediction#
train_pred = model_train.predict(train)

# %%
##train residual values#
train_resid= train_pred - train.price

# %%
##rmse value for train data#
train_rmse= np.sqrt(np.mean(train_resid*train_resid))
train_rmse
# Out:
# 279.5890608837146

# %% [markdown]
# PROBLEM 3#

# %%
import pandas as pd
import numpy as np

# %%
car = pd.read_csv('D:\\DATA SCIENCE ASSIGNMENT\\Datasets_MLR\\ToyotaCorolla.csv', encoding='latin-1')

# %%
car
# Out:
#       Price  Age_08_04     KM   HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0     13500         23  46986   90  2000      3      5            210    1165
# 1     13750         23  72937   90  2000      3      5            210    1165
# 2     13950         24  41711   90  2000      3      5            210    1165
# 3     14950         26  48000   90  2000      3      5            210    1165
# 4     13750         30  38500   90  2000      3      5            210    1170
# ...     ...        ...    ...  ...   ...    ...    ...            ...     ...
# 1431   7500         69  20544   86  1300      3      5             69    1025
# 1432  10845         72  19000   86  1300      3      5             69    1015
# 1433   8500         71  17016   86  1300      3      5             69    1015
# 1434   7250         70  16916   86  1300      3      5             69    1015
# 1435   6950         76      1  110  1600      5      5             19    1114
#
# [1436 rows x 9 columns]

# %%
car.head(5)
# Out:
#    Id                                           Model  Price  Age_08_04  \
# 0   1   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500         23
# 1   2   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750         23
# 2   3   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950         24
# 3   4   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950         26
# 4   5     TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750         30
#
#    Mfg_Month  Mfg_Year     KM Fuel_Type  HP  Met_Color  ... Central_Lock  \
# 0         10      2002  46986    Diesel  90          1  ...            1
# 1         10      2002  72937    Diesel  90          1  ...            1
# 2          9      2002  41711    Diesel  90          1  ...            0
# 3          7      2002  48000    Diesel  90          0  ...            0
# 4          3      2002  38500    Diesel  90          0  ...            1
#
#    Powered_Windows  Power_Steering  Radio  Mistlamps  Sport_Model  \
# ...

# %%
car.describe()
# Out:
#                 Id         Price    Age_08_04    Mfg_Month     Mfg_Year  \
# count  1436.000000   1436.000000  1436.000000  1436.000000  1436.000000
# mean    721.555014  10730.824513    55.947075     5.548747  1999.625348
# std     416.476890   3626.964585    18.599988     3.354085     1.540722
# min       1.000000   4350.000000     1.000000     1.000000  1998.000000
# 25%     361.750000   8450.000000    44.000000     3.000000  1998.000000
# 50%     721.500000   9900.000000    61.000000     5.000000  1999.000000
# 75%    1081.250000  11950.000000    70.000000     8.000000  2001.000000
# max    1442.000000  32500.000000    80.000000    12.000000  2004.000000
#
#                   KM           HP    Met_Color    Automatic           cc  ...  \
# count    1436.000000  1436.000000  1436.000000  1436.000000   1436.00000  ...
# mean    68533.259749   101.502089     0.674791     0.055710   1576.85585  ...
# std     37506.448872    14.981080     0.468616     0.229441    424.38677  ...
# ...

# %%
#using only required col#
cols = ['Price','Age_08_04','KM','HP','cc','Doors','Gears','Quarterly_Tax','Weight']
car= car[cols]

# %%
car.describe()
# Out:
#               Price    Age_08_04             KM           HP           cc  \
# count   1436.000000  1436.000000    1436.000000  1436.000000   1436.00000
# mean   10730.824513    55.947075   68533.259749   101.502089   1576.85585
# std     3626.964585    18.599988   37506.448872    14.981080    424.38677
# min     4350.000000     1.000000       1.000000    69.000000   1300.00000
# 25%     8450.000000    44.000000   43000.000000    90.000000   1400.00000
# 50%     9900.000000    61.000000   63389.500000   110.000000   1600.00000
# 75%    11950.000000    70.000000   87020.750000   110.000000   1600.00000
# max    32500.000000    80.000000  243000.000000   192.000000  16000.00000
#
#              Doors        Gears  Quarterly_Tax      Weight
# count  1436.000000  1436.000000    1436.000000  1436.00000
# mean      4.033426     5.026462      87.122563  1072.45961
# std       0.952677     0.188510      41.128611    52.64112
# min       2.000000     3.000000      19.000000  1000.00000
# ...

# %%
##graphical representation#
import matplotlib.pyplot as plt

# %%
#Price# 
plt.bar(height=car.Price, x=np.arange(1,1437,1))#barplot#
# Out:
# <BarContainer object of 1436 artists>

# %%
plt.hist(car.Price)#histogram#
# Out:
# (array([110., 706., 343., 114.,  75.,  59.,  22.,   4.,   0.,   3.]),
#  array([ 4350.,  7165.,  9980., 12795., 15610., 18425., 21240., 24055.,
#         26870., 29685., 32500.]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(car.Price)#boxplot#
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2036eb41c30>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2036eb421d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2036eb40a30>],
#  'medians': [<matplotlib.lines.Line2D at 0x2036eb42770>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2036eb42a40>],
#  'means': []}

# %%
#Age_08_04#
plt.bar(height=car.Age_08_04,x=np.arange(1,1437,1))#barplot
# Out:
# <BarContainer object of 1436 artists>

# %%
plt.hist(car.Age_08_04)#histogram#
# Out:
# (array([ 24.,  36.,  62.,  64., 108., 127., 182., 247., 287., 299.]),
#  array([ 1. ,  8.9, 16.8, 24.7, 32.6, 40.5, 48.4, 56.3, 64.2, 72.1, 80. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(car.Age_08_04)#boxplot#
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2036f590bb0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2036f591150>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2036f5908e0>],
#  'medians': [<matplotlib.lines.Line2D at 0x2036f5916f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2036f5919c0>],
#  'means': []}

# %%
#Jointplot#
import seaborn as sns

# %%
sns.jointplot(x=car['Age_08_04'], y=car['Price'])

# %%
##countplt#
plt.figure(1,figsize=(16,10))
sns.countplot(car['KM'])
# Out:
# C:\Users\Rakesh\.conda\envs\spyder-cf\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='KM', ylabel='count'>

# %%
##Q-Q plot#
from scipy import stats
import pylab

# %%
stats.probplot(car.Price, dist= 'norm', plot= pylab)
plt.show()

# %%
##Scatter plot btw variables along with histogrm#
sns.pairplot(car.iloc[:, :])

# %%
##correlation matrix#
car.corr()
# Out:
#                   Price  Age_08_04        KM        HP        cc     Doors  \
# Price          1.000000  -0.876590 -0.569960  0.314990  0.126389  0.185326
# Age_08_04     -0.876590   1.000000  0.505672 -0.156622 -0.098084 -0.148359
# KM            -0.569960   0.505672  1.000000 -0.333538  0.102683 -0.036197
# HP             0.314990  -0.156622 -0.333538  1.000000  0.035856  0.092424
# cc             0.126389  -0.098084  0.102683  0.035856  1.000000  0.079903
# Doors          0.185326  -0.148359 -0.036197  0.092424  0.079903  1.000000
# Gears          0.063104  -0.005364  0.015023  0.209477  0.014629 -0.160141
# Quarterly_Tax  0.219197  -0.198431  0.278165 -0.298432  0.306996  0.109363
# Weight         0.581198  -0.470253 -0.028598  0.089614  0.335637  0.302618
#
#                   Gears  Quarterly_Tax    Weight
# Price          0.063104       0.219197  0.581198
# Age_08_04     -0.005364      -0.198431 -0.470253
# KM             0.015023       0.278165 -0.028598
# ...

# %%
##preparing models for all variable#
import statsmodels.formula.api as smf

# %%
ml1 = smf.ols('Price~Age_08_04+KM+HP+cc+Doors+Gears+Quarterly_Tax+Weight' ,data=car).fit()#regression model#
ml1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.864
# Model:                            OLS   Adj. R-squared:                  0.863
# Method:                 Least Squares   F-statistic:                     1131.
# Date:                Sun, 28 Aug 2022   Prob (F-statistic):               0.00
# Time:                        16:07:28   Log-Likelihood:                -12376.
# No. Observations:                1436   AIC:                         2.477e+04
# Df Residuals:                    1427   BIC:                         2.482e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
##doors,CC variable has high P value#
##checking for any influential values
import statsmodels.api as sm

# %%
sm.graphics.influence_plot(ml1)

# %% [markdown]
#  index 80 is showing high influence so we can exclude that entire row

# %%
car_new= car.drop(car.index[[80]])

# %%
##preparing model#
ml_new= smf.ols('Price~Age_08_04+KM+HP+cc+Doors+Gears+Quarterly_Tax+Weight' ,data=car_new).fit()
ml_new.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.869
# Model:                            OLS   Adj. R-squared:                  0.869
# Method:                 Least Squares   F-statistic:                     1186.
# Date:                Sun, 28 Aug 2022   Prob (F-statistic):               0.00
# Time:                        16:11:18   Log-Likelihood:                -12335.
# No. Observations:                1435   AIC:                         2.469e+04
# Df Residuals:                    1426   BIC:                         2.473e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
# Check for Colinearity to decide to remove a variable using VIF
# Assumption: VIF > 10 = colinearity
# calculating VIF's values of independent variables

# %%
rsq_Age = smf.ols('Age_08_04 ~ KM + HP + cc + Doors + Gears + Quarterly_Tax + Weight', data = car).fit().rsquared  
vif_Age = 1/(1 - rsq_Age) 
vif_Age
# Out:
# 1.8846198056602872

# %%
rsq_KM = smf.ols('KM~Age_08_04 + HP + cc + Doors + Gears + Quarterly_Tax + Weight', data = car).fit().rsquared  
vif_KM = 1/(1 - rsq_KM) 
vif_KM
# Out:
# 1.7569047782042888

# %%
rsq_HP = smf.ols('HP~Age_08_04 + KM + cc + Doors + Gears + Quarterly_Tax + Weight', data = car).fit().rsquared  
vif_HP = 1/(1 - rsq_HP) 
vif_HP
# Out:
# 1.4194221086310972

# %%
rsq_cc = smf.ols('cc~Age_08_04 + KM + HP + Doors + Gears + Quarterly_Tax + Weight', data = car).fit().rsquared  
vif_cc = 1/(1 - rsq_cc)

# %%
rsq_Doors = smf.ols('Doors~Age_08_04 + KM + HP + cc + Gears + Quarterly_Tax + Weight', data = car).fit().rsquared  
vif_Doors = 1/(1 - rsq_Doors) 
vif_Doors
# Out:
# 1.1565752070760438

# %%
rsq_Gears = smf.ols('Gears~Age_08_04 + KM + HP + cc + Doors + Quarterly_Tax + Weight', data = car).fit().rsquared  
vif_Gears = 1/(1 - rsq_Gears) 
vif_Gears
# Out:
# 1.098723019347037

# %%
rsq_Tax = smf.ols('Quarterly_Tax~Age_08_04 + KM + HP + cc + Doors + Gears + Weight', data = car).fit().rsquared  
vif_Tax = 1/(1 - rsq_Tax) 
vif_Tax
# Out:
# 2.311430811531037

# %%
rsq_Weight = smf.ols('Weight~Age_08_04 + KM + HP + cc + Doors + Gears + Quarterly_Tax', data = car).fit().rsquared  
vif_Weight = 1/(1 - rsq_Weight) 
vif_Weight
# Out:
# 2.516419837445869

# %%
car.columns
# Out:
# Index(['Price', 'Age_08_04', 'KM', 'HP', 'cc', 'Doors', 'Gears',
#        'Quarterly_Tax', 'Weight'],
#       dtype='object')

# %%
##storing VIF value in a data frame#
d1 = {'Variable':['Age_08_04','KM','HP','cc','Doors','Gears','Quarterly_Tax','Weight'], 'VIF':['vif_Age','vif_KM','vif_HP','vif_cc','vif_Doors','vif_Gears','vif_Tax','vif_Weight']}
Vif_frame= pd.DataFrame(d1)
Vif_frame
# Out:
#         Variable         VIF
# 0      Age_08_04     vif_Age
# 1             KM      vif_KM
# 2             HP      vif_HP
# 3             cc      vif_cc
# 4          Doors   vif_Doors
# 5          Gears   vif_Gears
# 6  Quarterly_Tax     vif_Tax
# 7         Weight  vif_Weight

# %% [markdown]
# ##since there is no VIF value >10 we are not going to drop  any from prediction model#

# %%
#final model#
final_ml = smf.ols('Price~Age_08_04+KM+HP+cc+Doors+Gears+Quarterly_Tax+Weight' ,data=car).fit()
final_ml.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.864
# Model:                            OLS   Adj. R-squared:                  0.863
# Method:                 Least Squares   F-statistic:                     1131.
# Date:                Sun, 28 Aug 2022   Prob (F-statistic):               0.00
# Time:                        16:23:30   Log-Likelihood:                -12376.
# No. Observations:                1436   AIC:                         2.477e+04
# Df Residuals:                    1427   BIC:                         2.482e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
##prediction#
pred =final_ml.predict(car)

# %%
#Q-Q plot#
res = final_ml.resid
sm.qqplot(res)
plt.show()

# %%
stats.probplot(res,dist= 'norm', plot = pylab)
plt.show()

# %%
# Residuals vs Fitted plot#
sns.residplot(x=pred , y= car.Price,lowess= True)
plt.xlabel('Residuals')
plt.ylabel('Fitted')
plt.title('Residuals vs Fitted')
plt.show()

# %%
sm.graphics.influence_plot(final_ml)

# %%
##splitting train test data#
from sklearn.model_selection import train_test_split

# %%
car_train , car_test = train_test_split(car_new, test_size= 0.2)

# %%
##preparing the model on train data#
model_train = smf.ols('Price~Age_08_04+KM+HP+cc+Doors+Gears+Quarterly_Tax+Weight' ,data=car_train).fit()

# %%
##predcition on test data#
test_pred = model_train.predict(car_test)

# %%
##test residual value#
test_resid= test_pred - car_test.Price

# %%
##rmse value for test data#
test_rmse = np.sqrt(np.mean(test_resid*test_resid))
test_rmse
# Out:
# 1340.7364075894927

# %%
##prediction of train data#
train_pred = model_train.predict(car_train)

# %%
##train resiual value#
train_resid = train_pred -car_train.Price

# %%
##rmse value for train data#
train_rmse = np.sqrt(np.mean(train_resid*train_resid))
train_rmse
# Out:
# 1304.8837514314257

# %% [markdown]
# PROBLEM 4#

# %%
import pandas as pd
import numpy as np

# %%
##loading dataset
avacado = pd.read_csv('D:\\DATA SCIENCE ASSIGNMENT\\Datasets_MLR\\Avacado_Price.csv')

# %%
avacado.head(5)
# Out:
#    AveragePrice  Total_Volume  tot_ava1   tot_ava2  tot_ava3  Total_Bags  \
# 0          1.33      64236.62   1036.74   54454.85     48.16     8696.87
# 1          1.35      54876.98    674.28   44638.81     58.33     9505.56
# 2          0.93     118220.22    794.70  109149.67    130.50     8145.35
# 3          1.08      78992.15   1132.00   71976.41     72.58     5811.16
# 4          1.28      51039.60    941.48   43838.39     75.78     6183.95
#
#    Small_Bags  Large_Bags  XLarge Bags          type  year  region
# 0     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5677.40      133.76          0.0  conventional  2015  Albany
# 4     5986.26      197.69          0.0  conventional  2015  Albany

# %%
avacado.tail(5)
# Out:
#        AveragePrice  Total_Volume  tot_ava1  tot_ava2  tot_ava3  Total_Bags  \
# 18244          1.63      17074.83   2046.96   1529.20      0.00    13498.67
# 18245          1.71      13888.04   1191.70   3431.50      0.00     9264.84
# 18246          1.87      13766.76   1191.92   2452.79    727.94     9394.11
# 18247          1.93      16205.22   1527.63   2981.04    727.01    10969.54
# 18248          1.62      17489.58   2894.77   2356.13    224.53    12014.15
#
#        Small_Bags  Large_Bags  XLarge Bags     type  year            region
# 18244    13066.82      431.85          0.0  organic  2018  WestTexNewMexico
# 18245     8940.04      324.80          0.0  organic  2018  WestTexNewMexico
# 18246     9351.80       42.31          0.0  organic  2018  WestTexNewMexico
# 18247    10919.54       50.00          0.0  organic  2018  WestTexNewMexico
# 18248    11988.14       26.01          0.0  organic  2018  WestTexNewMexico

# %%
#EDA #
avacado.describe()
# Out:
#        AveragePrice  Total_Volume      tot_ava1      tot_ava2      tot_ava3  \
# count  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04
# mean       1.405978  8.506440e+05  2.930084e+05  2.951546e+05  2.283974e+04
# std        0.402677  3.453545e+06  1.264989e+06  1.204120e+06  1.074641e+05
# min        0.440000  8.456000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# 25%        1.100000  1.083858e+04  8.540700e+02  3.008780e+03  0.000000e+00
# 50%        1.370000  1.073768e+05  8.645300e+03  2.906102e+04  1.849900e+02
# 75%        1.660000  4.329623e+05  1.110202e+05  1.502069e+05  6.243420e+03
# max        3.250000  6.250565e+07  2.274362e+07  2.047057e+07  2.546439e+06
#
#          Total_Bags    Small_Bags    Large_Bags    XLarge Bags          year
# count  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000  18249.000000
# mean   2.396392e+05  1.821947e+05  5.433809e+04    3106.426507   2016.147899
# ...

# %%
##column remane#
cols = {'XLarge Bags' :'XLarge_Bags'}
avacado.rename(cols, axis = 1 , inplace = True)

# %%
avacado.columns
# Out:
# Index(['AveragePrice', 'Total_Volume', 'tot_ava1', 'tot_ava2', 'tot_ava3',
#        'Total_Bags', 'Small_Bags', 'Large_Bags', 'XLarge_Bags', 'type', 'year',
#        'region'],
#       dtype='object')

# %%
##dropinf year and region as it doesnt add any value to dataset#
avacado.drop(['year','region'], axis=1 , inplace= True)

# %%
avacado.columns #recheck#
# Out:
# Index(['AveragePrice', 'Total_Volume', 'tot_ava1', 'tot_ava2', 'tot_ava3',
#        'Total_Bags', 'Small_Bags', 'Large_Bags', 'XLarge_Bags', 'type'],
#       dtype='object')

# %%
##label encoding for categorical data#
from sklearn.preprocessing import LabelEncoder

# %%
L_enc = LabelEncoder()

# %%
avacado['type'] = L_enc.fit_transform(avacado['type'])

# %%
##Graphical representation#
import matplotlib.pyplot as plt

# %%
avacado.columns
# Out:
# Index(['AveragePrice', 'Total_Volume', 'tot_ava1', 'tot_ava2', 'tot_ava3',
#        'Total_Bags', 'Small_Bags', 'Large_Bags', 'XLarge_Bags', 'type'],
#       dtype='object')

# %%
##Averageprice#
plt.bar(height= avacado.AveragePrice,x=np.arange(1,18250,1))#barplot
# Out:
# <BarContainer object of 18249 artists>

# %%
plt.hist(avacado.AveragePrice)#histogram#
# Out:
# (array([ 331., 2632., 4824., 4506., 3412., 1672.,  598.,  177.,   86.,
#           11.]),
#  array([0.44 , 0.721, 1.002, 1.283, 1.564, 1.845, 2.126, 2.407, 2.688,
#         2.969, 3.25 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(avacado.AveragePrice)#boxplot
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2030580aef0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2030580b490>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x20305809c00>],
#  'medians': [<matplotlib.lines.Line2D at 0x2030580ba30>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2030580bd00>],
#  'means': []}

# %%
#tot_ava1#
plt.bar(height= avacado.tot_ava1,x=np.arange(1,18250,1))
# Out:
# <BarContainer object of 18249 artists>

# %%
plt.hist(avacado.tot_ava1)
# Out:
# (array([1.7699e+04, 3.7700e+02, 4.0000e+00, 2.0000e+01, 4.6000e+01,
#         6.7000e+01, 2.6000e+01, 7.0000e+00, 1.0000e+00, 2.0000e+00]),
#  array([       0.   ,  2274361.617,  4548723.234,  6823084.851,
#          9097446.468, 11371808.085, 13646169.702, 15920531.319,
#         18194892.936, 20469254.553, 22743616.17 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(avacado.tot_ava1)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20311f81210>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x20311f817b0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x20311f80f40>],
#  'medians': [<matplotlib.lines.Line2D at 0x20311f81d50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20311f82020>],
#  'means': []}

# %%
#jointplot#
import seaborn as sns

# %%
sns.jointplot(x=avacado['tot_ava1'],y=avacado['tot_ava3'])

# %%
##counplot#
plt.figure(1,figsize=(16,10))
sns.countplot(avacado['AveragePrice'])
# Out:
# C:\Users\Rakesh\.conda\envs\spyder-cf\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='AveragePrice', ylabel='count'>

# %%
##q-q plot#
from scipy import stats
import pylab

# %%
stats.probplot(avacado.AveragePrice,dist = 'norm' , plot=pylab)
plt.show()

# %%
##scatter plot btw variables along with histogram#
import seaborn as sns
sns.pairplot(avacado.iloc[:,:])

# %%
#correlation matrix#
avacado.corr()
# Out:
#               AveragePrice  Total_Volume  tot_ava1  tot_ava2  tot_ava3  \
# AveragePrice      1.000000     -0.192752 -0.208317 -0.172928 -0.179446
# Total_Volume     -0.192752      1.000000  0.977863  0.974181  0.872202
# tot_ava1         -0.208317      0.977863  1.000000  0.926110  0.833389
# tot_ava2         -0.172928      0.974181  0.926110  1.000000  0.887855
# tot_ava3         -0.179446      0.872202  0.833389  0.887855  1.000000
# Total_Bags       -0.177088      0.963047  0.920057  0.905787  0.792314
# Small_Bags       -0.174730      0.967238  0.925280  0.916031  0.802733
# Large_Bags       -0.172940      0.880640  0.838645  0.810015  0.698471
# XLarge_Bags      -0.117592      0.747157  0.699377  0.688809  0.679861
# type              0.615845     -0.232434 -0.225819 -0.232289 -0.210027
#
#               Total_Bags  Small_Bags  Large_Bags  XLarge_Bags      type
# AveragePrice   -0.177088   -0.174730   -0.172940    -0.117592  0.615845
# ...

# %%
##preparing model for all variable#
import statsmodels.formula.api as smf

# %%
#regression model#
ml1 = smf.ols('AveragePrice ~ Total_Volume + tot_ava1 + tot_ava2 + tot_ava3 + Total_Bags + Small_Bags + Large_Bags + XLarge_Bags + type', data = avacado).fit()
ml1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           AveragePrice   R-squared:                       0.398
# Model:                            OLS   Adj. R-squared:                  0.398
# Method:                 Least Squares   F-statistic:                     1340.
# Date:                Sun, 28 Aug 2022   Prob (F-statistic):               0.00
# Time:                        18:44:38   Log-Likelihood:                -4662.2
# No. Observations:               18249   AIC:                             9344.
# Df Residuals:                   18239   BIC:                             9423.
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %% [markdown]
# #p value is high in many columns

# %%
##checking for any influential value#
import statsmodels.api as sm

# %%
sm.graphics.influence_plot(ml1)

# %% [markdown]
# # index 17468 is showing high influence so we can exclude that entire row

# %%
avacado2 = avacado.drop(avacado.index[[17468]])

# %%
##preparing new model#
ml_new = smf.ols('AveragePrice ~ Total_Volume + tot_ava1 + tot_ava2 + tot_ava3 + Total_Bags + Small_Bags + Large_Bags + XLarge_Bags + type', data = avacado2).fit()
ml_new.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           AveragePrice   R-squared:                       0.398
# Model:                            OLS   Adj. R-squared:                  0.398
# Method:                 Least Squares   F-statistic:                     1340.
# Date:                Sun, 28 Aug 2022   Prob (F-statistic):               0.00
# Time:                        18:52:11   Log-Likelihood:                -4662.1
# No. Observations:               18248   AIC:                             9344.
# Df Residuals:                   18238   BIC:                             9422.
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
avacado.columns
# Out:
# Index(['AveragePrice', 'Total_Volume', 'tot_ava1', 'tot_ava2', 'tot_ava3',
#        'Total_Bags', 'Small_Bags', 'Large_Bags', 'XLarge_Bags', 'type'],
#       dtype='object')

# %%
# Check for Colinearity to decide to remove a variable using VIF#
# Assumption: VIF > 10 = colinearity#
# calculating VIF's values of independent variables#
rsq_Total_Volume = smf.ols('Total_Volume ~ tot_ava1 + tot_ava2 + tot_ava3 + Total_Bags + Small_Bags + Large_Bags + XLarge_Bags + type', data = avacado).fit().rsquared  
vif_Total_Volume = 1/(1 - rsq_Total_Volume) 
vif_Total_Volume
# Out:
# 4913535930.011342

# %%
rsq_tot_ava1 = smf.ols('tot_ava1 ~ Total_Volume + tot_ava2 + tot_ava3 + Total_Bags + Small_Bags + Large_Bags + XLarge_Bags + type', data = avacado).fit().rsquared  
vif_tot_ava1 = 1/(1 - rsq_tot_ava1) 
vif_tot_ava1
# Out:
# 659225031.0221928

# %%
rsq_tot_ava2 = smf.ols('tot_ava2 ~ Total_Volume + tot_ava1 + tot_ava3 + Total_Bags + Small_Bags + Large_Bags + XLarge_Bags + type', data = avacado).fit().rsquared  
vif_tot_ava2 = 1/(1 - rsq_tot_ava2) 
vif_tot_ava2
# Out:
# 597312085.7588413

# %%
rsq_tot_ava3 = smf.ols('tot_ava3 ~ Total_Volume + tot_ava1 + tot_ava2 + Total_Bags + Small_Bags + Large_Bags + XLarge_Bags + type', data = avacado).fit().rsquared  
vif_tot_ava3 = 1/(1 - rsq_tot_ava3) 
vif_tot_ava3
# Out:
# 4757707.409914284

# %%
rsq_Total_Bags = smf.ols('Total_Bags ~ Total_Volume + tot_ava1 + tot_ava2 + tot_ava3 + Small_Bags + Large_Bags + XLarge_Bags + type', data = avacado).fit().rsquared  
vif_Total_Bags = 1/(1 - rsq_Total_Bags) 
vif_Total_Bags
# Out:
# 237031559335289.25

# %%
rsq_Small_Bags = smf.ols('Small_Bags ~ Total_Volume + tot_ava1 + tot_ava2 + tot_ava3 + Total_Bags + Large_Bags + XLarge_Bags + type', data = avacado).fit().rsquared  
vif_Small_Bags = 1/(1 - rsq_Small_Bags) 
vif_Small_Bags
# Out:
# 136472715980924.12

# %%
rsq_Large_Bags = smf.ols('Large_Bags ~ Total_Volume + tot_ava1 + tot_ava2 + tot_ava3 + Total_Bags + Small_Bags + XLarge_Bags + type', data = avacado).fit().rsquared  
vif_Large_Bags = 1/(1 - rsq_Large_Bags) 
vif_Large_Bags
# Out:
# 14481027740741.145

# %%
rsq_XLarge_Bags = smf.ols('XLarge_Bags ~ Total_Volume + tot_ava1 + tot_ava2 + tot_ava3 + Total_Bags + Small_Bags + Large_Bags + type', data = avacado).fit().rsquared  
vif_XLarge_Bags = 1/(1 - rsq_XLarge_Bags) 
vif_XLarge_Bags
# Out:
# 76204973516.59511

# %%
rsq_type = smf.ols('type ~ Total_Volume + tot_ava1 + tot_ava2 + tot_ava3 + Total_Bags + Small_Bags + Large_Bags + XLarge_Bags', data = avacado).fit().rsquared  
vif_type = 1/(1 - rsq_type) 
vif_type
# Out:
# 1.060180753381593

# %%
avacado.columns
# Out:
# Index(['AveragePrice', 'Total_Volume', 'tot_ava1', 'tot_ava2', 'tot_ava3',
#        'Total_Bags', 'Small_Bags', 'Large_Bags', 'XLarge_Bags', 'type'],
#       dtype='object')

# %%
# Storing vif values in a data frame
d1 = {'Variables':['Total_Volume','tot_ava1','tot_ava2','tot_ava3','Total_Bags','Small_Bags','Large_Bags','XLarge_Bags', 'type'], 'VIF':[vif_Total_Volume, vif_tot_ava1, vif_tot_ava2, vif_tot_ava3 , vif_Total_Bags , vif_Small_Bags , vif_Large_Bags , vif_XLarge_Bags, vif_type]}
Vif_frame = pd.DataFrame(d1)  
Vif_frame
# Out:
#       Variables           VIF
# 0  Total_Volume  4.913536e+09
# 1      tot_ava1  6.592250e+08
# 2      tot_ava2  5.973121e+08
# 3      tot_ava3  4.757707e+06
# 4    Total_Bags  2.370316e+14
# 5    Small_Bags  1.364727e+14
# 6    Large_Bags  1.448103e+13
# 7   XLarge_Bags  7.620497e+10
# 8          type  1.060181e+00

# %%
#final model#
final_ml = smf.ols('AveragePrice ~ Total_Volume + tot_ava1 + tot_ava2 + tot_ava3 + Total_Bags + Small_Bags + Large_Bags + XLarge_Bags + type', data = avacado).fit()
final_ml.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           AveragePrice   R-squared:                       0.398
# Model:                            OLS   Adj. R-squared:                  0.398
# Method:                 Least Squares   F-statistic:                     1340.
# Date:                Sun, 28 Aug 2022   Prob (F-statistic):               0.00
# Time:                        19:07:05   Log-Likelihood:                -4662.2
# No. Observations:               18249   AIC:                             9344.
# Df Residuals:                   18239   BIC:                             9423.
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
#prediction#
pred= final_ml.predict(avacado)

# %%
##Q-Q plot#
res = final_ml.resid
sm.qqplot(res)
plt.show()

# %%
stats.probplot(res, dist='norm', plot=pylab)
plt.show()

# %%
##residual vs fitted
sns.residplot(x=pred , y= avacado.AveragePrice,lowess= True)
plt.xlabel('Residuals')
plt.ylabel('Fitted')
plt.title('Residuals vs Fitted')
plt.show()

# %%
sm.graphics.influence_plot(final_ml)

# %%
##splitting train & test data#
from sklearn.model_selection import train_test_split

# %%
train,test = train_test_split(avacado,test_size= 0.2)

# %%
##preparing model on train data#
model_train = smf.ols('AveragePrice ~ Total_Volume + tot_ava1 + tot_ava2 + tot_ava3 + Total_Bags + Small_Bags + Large_Bags + XLarge_Bags + type', data = train).fit()

# %%
##prediction on test data#
test_pred = model_train.predict(test)

# %%
##test residual values#
test_resid = test_pred-test.AveragePrice

# %%
##RMSE values for test data#
test_rmse = np.sqrt(np.mean(test_resid*test_resid))
test_rmse
# Out:
# 0.315222923129594

# %%
##train data prediction#
train_pred = model_train.predict(train)

# %%
##train residual values#
train_resid = train_pred-train.AveragePrice

# %%
##RMSE values for test data#
train_rmse = np.sqrt(np.mean(train_resid*train_resid))
train_rmse
# Out:
# 0.31171214976048284
